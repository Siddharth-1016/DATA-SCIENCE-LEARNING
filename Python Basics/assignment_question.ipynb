# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World !!")
# Out:
# Hello World !!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name = "Siddharth"
surname = "Tripathi"

print(name + " " + surname)
# Out:
# Siddharth Tripathi

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
a = int(input("Enter a number : "))

if(a > 0):
    print("Positive")
elif(a == 0):
    print("Zero")
else:
    print("Negative")
# Out:
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a = 5
b = 2
c = 3

if(a>b and a>c):
    print(a)
elif(a<b and c<b):
    print(b)
else:
    print(c)
# Out:
# 5

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here

def factorial(a):
    if a==1:
        return 1
    else:
        return a*factorial(a-1)

a = int(input("Enter a number: "))
ans = factorial(a)
print(ans)
# Out:
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a = int(input("Enter an integer: "))
b = float(input("Enter a float number: "))
c = str(input("Enter a string: "))
d = bool(input("Enter a boolean: "))

print(f"Value is  {a}  and it's data type is  {type(a)}")
print(f"Value is  {b}  and it's data type is  {type(b)}")
print(f"Value is  {c}  and it's data type is  {type(c)}")
print(f"Value is  {d}  and it's data type is  {type(d)}")
# Out:
# Value is  5  and it's data type is  <class 'int'>
# Value is  12.45  and it's data type is  <class 'float'>
# Value is  sid  and it's data type is  <class 'str'>
# Value is  True  and it's data type is  <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
def swap_num(a, b):
    return b, a

a = 5
b = 4

a, b = swap_num(a, b) 

print(a)
print(b)
# Out:
# 4
# 5

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
def cel_to_far(celsius):
    faren = (celsius * 9/5) + 32
    return faren

celsius = float(input("Enter the temperatue in celsius: "))

print(f"Conversion of temperature from {celsius} celsius to farenhiet = {cel_to_far(celsius)}")
# Out:
# Conversion of temperature from 29.5 celsius to farenhiet = 85.1

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
a = "Siddharth"
b = " Tripathi"

print(a+b)
# Out:
# Siddharth Tripathi

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 5
b = 4

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 9
# 1
# 20
# 1.25

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 5
b = 3

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
# Out:
# 5 == 3: False
# 5 != 3: True
# 5 > 3: True
# 5 < 3: False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False

print(f"Result of and operator : {a and b}")
print(f"Result of or operator : {a or b}")
print(f"Result of not operator :{not a}")
# Out:
# Result of and operator : False
# Result of or operator : True
# Result of not operator :False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
a = int(input("Enter a number: "))

print(a*a)
# Out:
# 25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
a = int(input("Enter a number: "))

if(a%2 == 0):
    print(f"{a} is an Even number")
else:
    print(f"{a} is an Odd number")
# Out:
# 5 is an Odd number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

def solve(n):
    if(n==0):
        return 0
    else:
        return n + solve(n-1)

n = int(input("Enter a number: "))

print(f"Sum of {n} natural number is {solve(n)}")
# Out:
# Sum of 10 natural number is 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
a = int(input("Enter the year: "))

if((a%4==0 and a%100==0) or (a%400==0)):
    print("{a} is a leap year")
else:
    print(f"{a} is not a leap year")
# Out:
# 1976 is not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
