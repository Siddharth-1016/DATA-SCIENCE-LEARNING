# %%
import pandas as pd
from io import StringIO
Data = '{"Employee Name":"Siddharth","Email":"sid.tripathi.0610@gmail.com","Job Profile":[{"Title1":"Team Lead","Title2":"Sr. Developer"}]}'
df = pd.read_json(StringIO(Data))

# %%
df
# Out:
#   Employee Name                        Email  \
# 0     Siddharth  sid.tripathi.0610@gmail.com
#
#                                          Job Profile
# 0  {'Title1': 'Team Lead', 'Title2': 'Sr. Develop...

# %%
df.to_json()
# Out:
# '{"Employee Name":{"0":"Siddharth"},"Email":{"0":"sid.tripathi.0610@gmail.com"},"Job Profile":{"0":{"Title1":"Team Lead","Title2":"Sr. Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"Employee Name":"Siddharth","Email":"sid.tripathi.0610@gmail.com","Job Profile":{"Title1":"Team Lead","Title2":"Sr. Developer"}}}'
